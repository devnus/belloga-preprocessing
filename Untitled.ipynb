# %%
from kafka import KafkaProducer
from json import dumps
import time

producer = KafkaProducer(acks=0, compression_type='gzip', bootstrap_servers=['13.209.250.13:9092'],api_version=(0, 10, 1),
                         value_serializer=lambda x: dumps(x).encode('utf-8'))

start = time.time()
for i in range(10000):
    print("hi")
    data = {'str' : 'result'+str(i)}
    producer.send('test', value=data)
    print("send")
    producer.flush()
print("elapsed :", time.time() - start)
# Out:
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# hi
# send
# ...

# %%
from kafka import KafkaConsumer
from json import loads

# topic, broker list
consumer = KafkaConsumer(
    'pay-tmp-point-to-labeler',
     bootstrap_servers=['13.209.250.13:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     group_id='my-group',
    api_version=(0, 10, 1),
     value_deserializer=lambda x: loads(x.decode('utf-8')),
     consumer_timeout_ms=1000
)

# %%
# consumer list를 가져온다
print('[begin] get consumer list')
for message in consumer:
    print("Topic: %s, Partition: %d, Offset: %d, Key: %s, Value: %s" % (
        message.topic, message.partition, message.offset, message.key, message.value
    ))
print('[end] get consumer list')
# Out:
# [begin] get consumer list
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 # consumer list를 가져온다
#       2 print('[begin] get consumer list')
# ----> 3 for message in consumer:
#       4     print("Topic: %s, Partition: %d, Offset: %d, Key: %s, Value: %s" % (
#       5         message.topic, message.partition, message.offset, message.key, message.value
#       6     ))
#       7 print('[end] get consumer list')
#
# File ~/.python-3.8/lib/python3.8/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/.python-3.8/lib/python3.8/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
# ...

# %%
import os
 
response = os.system("ping 13.209.250.13")
# Out:
# PING 13.209.250.13 (13.209.250.13): 56 data bytes
# Request timeout for icmp_seq 0
# Request timeout for icmp_seq 1
# Request timeout for icmp_seq 2
#
# --- 13.209.250.13 ping statistics ---
# 4 packets transmitted, 0 packets received, 100.0% packet loss

# %%
from kafka import KafkaConsumer

consumer = KafkaConsumer('data-preprocessing', bootstrap_servers='13.209.250.13:9092',
enable_auto_commit=True, auto_offset_reset='earliest')
for message in consumer: 
    print("Topic: {}, Partition: {}, Offset: {}, Key: {}, Value: {}".format( message.topic, message.partition, message.offset, message.key, message.value.decode('utf-8')))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Topic: data-preprocessing, Partition: 0, Offset: 9312, Key: None, Value: {"data": "{\"enterpriseId\": \"dusik\", \"rawDataId\": 1, \"imageUrl\": \"https://belloga-dev-s3-raw-data-bucket.s3.ap-northeast-2.amazonaws.com/dev-data/00000001+-+%EB%B3%B5%EC%82%AC%EB%B3%B8.png\", \"boundingBoxInfo\": [{\"x\": [63, 233, 233, 63], \"y\": [77, 77, 151, 151]}]}"}
# ...

# %%
print(type(1))
# Out:
# <class 'int'>
